# %% [markdown]
# # Project 1
# ECE 232E Summer 2026 - Project 1: Random Graphs and Random Walks
# Posted: Friday, June 26, 2026
# Due: Friday, July 10, 2026 at 11:59 PM PST

# %% [markdown]
# ## 1. Generating Random Networks

# %% [markdown]
# ### 1. Create random networks using Erdos-Renyi (ER) model

# %% [markdown]
# #### (a)

# %% [markdown]
# #### (b)

# %% [markdown]
# ### 2. Create networks using preferential attachment model

# %% [markdown]
# #### (a)

# %%
from project1_code import question_2a
question_2a()
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Yes, this network is always connected

# %% [markdown]
# #### (b)

# %%
from project1_code import question_2b
question_2b()
# Out:
# IGRAPH U--- 1050 1049 --
# connected: True
# max degree: 31
# mean degree: 1.9980952380952381
# degree variance: 5.034282086167801
# edges: 1049 , max degree: 31 , assortativity: -0.06122010661771199 , modularity: 0.931

# %% [markdown]
# #### (c)

# %%
from project1_code import question_2c
question_2c()
# Out:
# IGRAPH U--- 10500 10499 --
# connected: True
# max degree: 47
# mean degree: 1.9998095238095237
# degree variance: 5.0205713922902495
# edges: 10499 , max degree: 47 , assortativity: -0.053501633614794146 , modularity: 0.979

# %% [markdown]
# **Write observation comparing b and c

# %% [markdown]
# #### (d)

# %%
from project1_code import question_2d
question_2d()
# Out:
# rough log-log slope: -2.1518514865578555
# rough log-log slope: -2.4279410230296183

# %% [markdown]
# #### (e)

# %%
from project1_code import question_2e
question_2e(1050)
# Out:
# rough log-log slope: -0.8657706049370735

# %%
question_2e(10500)
# Out:
# rough log-log slope: -1.451076961668888

# %% [markdown]
# **Write down what you observe

# %% [markdown]
# #### (f)

# %%
from project1_code import question_2f
question_2f()

# %% [markdown]
# #### (g)

# %%
from project1_code import question_2g
question_2g(2)
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Yes, this network is always connected
# IGRAPH U--- 1050 2097 --
# connected: True
# max degree: 53
# mean degree: 3.994285714285714
# degree variance: 16.819014965986394
# edges: 2097 , assortativity: -0.0398799681680843 , modularity: 0.526
# Nodes:  1050 , m =  2
# rough log-log slope: -2.2148381042617387
# rough log-log slope: -0.9099336387089385
# IGRAPH U--- 10500 20997 --
# connected: True
# max degree: 170
# mean degree: 3.9994285714285716
# degree variance: 21.860761578231287
# edges: 20997 , assortativity: -0.003472528369105342 , modularity: 0.531
# Nodes:  10500 , m =  2
# rough log-log slope: -2.338698400944822
# rough log-log slope: -1.4187720888932998

# %%
question_2g(6)
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Yes, this network is always connected
# IGRAPH U--- 1050 6279 --
# connected: True
# max degree: 118
# mean degree: 11.96
# degree variance: 125.44601904761906
# edges: 6279 , assortativity: -0.01020373688909096 , modularity: 0.248
# Nodes:  1050 , m =  6
# rough log-log slope: -1.9786199146921055
# rough log-log slope: -1.0498378655839027
# IGRAPH U--- 10500 62979 --
# connected: True
# max degree: 339
# mean degree: 11.996
# degree variance: 191.38379352380954
# edges: 62979 , assortativity: 0.001498561145726318 , modularity: 0.245
# Nodes:  10500 , m =  6
# rough log-log slope: -2.1348361109392284
# rough log-log slope: -1.2036641394200642

# %% [markdown]
# **Write down observations

# %% [markdown]
# #### (h)

# %%
from project1_code import question_2h
question_2h()
# Out:
# Used Fastgreedy
# Modularity:  0.932
# Fastgreedy failed (Error at src/community/fast_modularity.c:652: Fast greedy community detection works only on graphs without multi-edges. -- Invalid value), Using Walktrap
# Modularity:  0.728

# %% [markdown]
# ### 3. Create a modified preferential attachment model that penalizes the age of a node

# %% [markdown]
# ## 2. Random Walk on Networks

# %% [markdown]
# ### 1. Random walk on Erdos-Renyi networks

# %% [markdown]
# ### 2. Random walk on networks with fat-tailed degree distribution

# %% [markdown]
# ### 3. PageRank

# %% [markdown]
# ### 4. Personalized PageRank
