# %% [markdown]
# # Project 1
# ECE 232E Summer 2026 - Project 1: Random Graphs and Random Walks
# Posted: Friday, June 26, 2026
# Due: Friday, July 10, 2026 at 11:59 PM PST

# %% [markdown]
# ## 1. Generating Random Networks

# %% [markdown]
# ### 1. Create random networks using Erdos-Renyi (ER) model

# %% [markdown]
# #### (a)

# %% [markdown]
# #### (b)

# %% [markdown]
# ### 2. Create networks using preferential attachment model

# %% [markdown]
# #### (a)

# %%
from project1_code import question_2a
question_2a()
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Yes, this network is always connected

# %% [markdown]
# #### (b)

# %%
from project1_code import question_2b
question_2b()
# Out:
# IGRAPH U--- 1050 1049 --
# connected: True
# max degree: 33
# mean degree: 1.9980952380952381
# degree variance: 4.826663038548753
# edges: 1049 , assortativity: -0.07057333568030286 , modularity: 0.933

# %% [markdown]
# #### (c)

# %%
from project1_code import question_2c
question_2c()
# Out:
# IGRAPH U--- 10500 10499 --
# connected: True
# max degree: 68
# mean degree: 1.9998095238095237
# degree variance: 5.307809487528344
# edges: 10499 , assortativity: -0.024681516975180128 , modularity: 0.979

# %% [markdown]
# **Write observation comparing b and c

# %% [markdown]
# #### (d)

# %%
from project1_code import question_2d
question_2d()
# Out:
# Nodes:  1050 , m =  1
# rough log-log slope: -2.134764540712606
# Nodes:  10500 , m =  1
# rough log-log slope: -2.54499189139138

# %% [markdown]
# #### (e)

# %%
from project1_code import question_2e
question_2e(1050)
# Out:
# rough log-log slope: -1.297738731356683

# %%
question_2e(10500)
# Out:
# rough log-log slope: -1.3054896518665167

# %% [markdown]
# **Write down what you observe

# %% [markdown]
# #### (f)

# %%
from project1_code import question_2f
question_2f()

# %% [markdown]
# #### (g)

# %%
from project1_code import question_2g
question_2g(2)
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Yes, this network is always connected
# IGRAPH U--- 1050 2097 --
# connected: True
# max degree: 50
# mean degree: 3.994285714285714
# degree variance: 18.21330068027211
# edges: 2097 , assortativity: -0.05841035507787053 , modularity: 0.528
# Nodes:  1050 , m =  2
# rough log-log slope: -2.2149402344529943
# rough log-log slope: -0.7759817816957496
# IGRAPH U--- 10500 20997 --
# connected: True
# max degree: 205
# mean degree: 3.9994285714285716
# degree variance: 22.835999673469384
# edges: 20997 , assortativity: -0.0011280487085171703 , modularity: 0.531
# Nodes:  10500 , m =  2
# rough log-log slope: -2.4078831099585627
# rough log-log slope: -1.2496921519286264

# %%
question_2g(6)
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Yes, this network is always connected
# IGRAPH U--- 1050 6279 --
# connected: True
# max degree: 118
# mean degree: 11.96
# degree variance: 135.2479238095238
# edges: 6279 , assortativity: -0.02279274298058022 , modularity: 0.245
# Nodes:  1050 , m =  6
# rough log-log slope: -1.963833184627428
# rough log-log slope: -1.034846464936595
# IGRAPH U--- 10500 62979 --
# connected: True
# max degree: 329
# mean degree: 11.996
# degree variance: 194.01579352380955
# edges: 62979 , assortativity: -0.003760643841353149 , modularity: 0.245
# Nodes:  10500 , m =  6
# rough log-log slope: -2.211006565214607
# rough log-log slope: -1.1397610134852632

# %% [markdown]
# **Write down observations

# %% [markdown]
# #### (h)

# %%
from project1_code import question_2h
question_2h()
# Out:
# Original Network
# Used Fastgreedy
# Modularity:  0.934
# New Network
# Fastgreedy failed (Error at src/community/fast_modularity.c:652: Fast greedy community detection works only on graphs without multi-edges. -- Invalid value), Using Walktrap
# Modularity:  0.744

# %% [markdown]
# ### 3. Create a modified preferential attachment model that penalizes the age of a node

# %% [markdown]
# ## 2. Random Walk on Networks

# %% [markdown]
# ### 1. Random walk on Erdos-Renyi networks

# %% [markdown]
# ### 2. Random walk on networks with fat-tailed degree distribution

# %% [markdown]
# ### 3. PageRank

# %% [markdown]
# ### 4. Personalized PageRank
